# %% [markdown]
# <a href="https://colab.research.google.com/github/Thasli-ma-2004/Data-Analytics-using-Python-Project/blob/main/Internship_day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.Series([10,20,30,40])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

data= pd.Series(
    [100,200,300,400],
    index=["ARUN" ,"BABU" ,"CHANDRU", "THASLIMA"]
)

print(data)
# Out:
# ARUN        100
# BABU        200
# CHANDRU     300
# THASLIMA    400
# dtype: int64

# %%
import pandas as pd

data={
    "Name":["Ram","Sita"],
    "Age":[25,30],
    "Deparetment":["HR","IT"]

}
df=pd.DataFrame(data)
print(df)
# Out:
#    Name  Age Deparetment
# 0   Ram   25          HR
# 1  Sita   30          IT

# %%
import pandas as pd
employee = {
    "ID":[101,102,103],
    "Name":["Arun","Kumar","Priya"],
    "Salary":[50000,60000,55000]
}
df=pd.DataFrame(employee)
print(df)
# Out:
#     ID   Name  Salary
# 0  101   Arun   50000
# 1  102  Kumar   60000
# 2  103  Priya   55000

# %%
#Product sales performance analysis
import numpy as np
products=["Laptop","Mobile","Tablet","TV","Refrigerator"]

sales=np.array([120,250,80,150,100])
print("Total Sales:",np.sum(sales))
print("Average Sales:",np.mean(sales))
print("Highest Sales:",np.max(sales))
print("Lowest Sales:",np.min(sales))

best_index=np.argmax(sales)
worst_index=np.argmin(sales)
print("Best Selling Product:",products[best_index])

print("\nProduct Sales Report")
for i in range(len(products)):
    print(f"{products[i]}: {sales[i]}")
# Out:
# Total Sales: 700
# Average Sales: 140.0
# Highest Sales: 250
# Lowest Sales: 80
# Best Selling Product: Mobile
#
# Product Sales Report
# Laptop: 120
# Mobile: 250
# Tablet: 80
# TV: 150
# Refrigerator: 100
