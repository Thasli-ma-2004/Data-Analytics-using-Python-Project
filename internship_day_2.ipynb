# %% [markdown]
# <a href="https://colab.research.google.com/github/Thasli-ma-2004/Data-Analytics-using-Python-Project/blob/main/internship_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hi Internship Students")
greet()
# Out:
# Hi Internship Students

# %%
def greet(name):
  print("Welcome",name)
greet("Mam")
# Out:
# Welcome Mam

# %%
def add(a,b):
  return a+b
result = add(10,20)
print(result)
# Out:
# 30

# %%
from google.colab import files
uploaded = files.upload()
file=open("Students List.txt","r")

data=file.read()

print(data)

file.close()
# Out:
#      <input type="file" id="files-5c00bf4f-ecec-46b2-aa3d-7349e9fb1325" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c00bf4f-ecec-46b2-aa3d-7349e9fb1325">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
file=open("customers-100.csv","r")

data=file.read()

print(data)

file.close()
# Out:
#      <input type="file" id="files-fd9633e5-db74-471b-92bb-0c2fe8258f5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd9633e5-db74-471b-92bb-0c2fe8258f5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
try:
  num= int(input("Enter Number:"))
  print(num)

except:
  print("Invalid Input")
# Out:
# Enter Number:123
# 123
